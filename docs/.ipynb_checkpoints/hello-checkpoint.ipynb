# %% [raw]
# ---
# title: "Education Data (Enrollment Analysis)"
# format:
#   html:
#     code-fold: true
# jupyter: python3
#
# ---

# %%
# Import necessary libraries
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# Load data from Google Sheets or CSV (assuming CSV format here)
url = "https://docs.google.com/spreadsheets/d/1GIbCJvwq3h6RyYvs8RlHGc87TSygv1Y03bapGVltlxw/edit?usp=sharing"
csv_export_url = url.replace('/edit#gid=', '/export?format=csv&gid=')
print(csv_export_url)
df = pd.read_csv(csv_export_url, on_bad_lines='skip', index_col=None)





# Trends Over Years
# Out:
# https://docs.google.com/spreadsheets/d/1GIbCJvwq3h6RyYvs8RlHGc87TSygv1Y03bapGVltlxw/edit?gid=1312810452#gid=1312810452

# %%
df
# Out:
#     <!DOCTYPE html><html lang="en-GB"><head><script nonce="HGENkV5s1W4axn1NqH6FQw">var DOCS_timing={}; DOCS_timing['pls']=new Date().getTime();</script><meta property="og:title" content="Open Enrollment 2023-24-clean"><meta property="og:type" content="article"><meta property="og:site_name" content="Google Docs"><meta property="og:url" content="https://docs.google.com/spreadsheets/d/1GIbCJvwq3h6RyYvs8RlHGc87TSygv1Y03bapGVltlxw/edit?gid=1312810452&amp;usp=embed_facebook"><meta property="og:image" content="https://lh7-us.googleusercontent.com/docs/AHkbwyKEoCFBLZN9glBEeumuzNj2q9T3kvMYsK5gBDBlYHooah4BQamQMmgYxk6MyKa7yvOsCDiXFyKpQ2djLENIskyPM37FVtOMzlonSDUNC-njt5hA6xg=w1200-h630-p"><meta property="og:image:width" content="1200"><meta property="og:image:height" content="630"><meta name="google" content="notranslate"><meta http-equiv="X-UA-Compatible" content="IE=edge;"><meta name="referrer" content="origin"><title>Open Enrollment 2023-24-clean - Google Sheets</title><link rel="shortcut icon" href="//ssl.gstatic.com/docs/spreadsheets/spreadsheets_2023q4.ico"><link rel="chrome-webstore-item" href="https://chrome.google.com/webstore/detail/apdfllckaahabafndbhieahigkjlhalf"><style nonce="Kr1M3dRSxhXZERh2pakjtQ">.gb_0d:not(.gb_ne){font:13px/27px Roboto  \
# 0                                                 try{
# 1    _._F_toggles_initialize=function(a){(typeof gl...
# 2                                                   /*
# 3               Copyright The Closure Library Authors.
# 4                  SPDX-License-Identifier: Apache-2.0
# ..                                                 ...
# 127                                  var Pj=function(a
# 128                     }catch(e){_._DumpException(e)}
# 129                                    })(this.gbar_);
# 130                                     // Google Inc.
# 131  </script><script nonce="HGENkV5s1W4axn1NqH6FQw...
#
#                              Arial  \
# 0                              NaN
# 1    _._F_toggles_initialize)([]);
# 2                              NaN
# 3                              NaN
# 4                              NaN
# ..                             ...
# 127                              b
# 128                            NaN
# 129                            NaN
# 130                            NaN
# 131                       slce:207
#
#     sans-serif;z-index:986}@-webkit-keyframes gb__a{0%{opacity:0}50%{opacity:1}}@keyframes gb__a{0%{opacity:0}50%{opacity:1}}.gb_9c{display:inline-block;padding:4px 4px 4px 4px;vertical-align:middle}.gb_Me .gb_O{bottom:-3px;right:-5px}.gb_9c:first-child  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 127                                      c){a<b?Oj(a+1
# 128                                                NaN
# 129                                                NaN
# 130                                                NaN
# 131                                              smc:3
#
#     #gbsfw:first-child+.gb_9c{padding-left:0}.gb_C{position:relative}.gb_A{display:inline-block;outline:none;vertical-align:middle;border-radius:2px;-moz-box-sizing:border-box;box-sizing:border-box;height:40px;width:40px;cursor:pointer;text-decoration:none}#gb#gb a.gb_A{cursor:pointer;text-decoration:none}.gb_A  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 127                   b):_.Xd.log(Error("pa`"+a+"`"+b)
# 128                                                NaN
# 129                                                NaN
# 130                                                NaN
# 131                                              smf:0
#
#     a.gb_A{color:#000}.gb_ad{border-color:transparent;border-bottom-color:#fff;border-style:dashed dashed solid;border-width:0 8.5px 8.5px;display:none;position:absolute;left:11.5px;top:33px;z-index:1;height:0;width:0;-webkit-animation:gb__a .2s;animation:gb__a .2s}.gb_bd{border-color:transparent;border-style:dashed dashed solid;border-width:0 8.5px 8.5px;display:none;position:absolute;left:11.5px;z-index:1;height:0;width:0;-webkit-animation:gb__a .2s;animation:gb__a .2s;border-bottom-color:rgba(0  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 127                                          {url:c})}
# 128                                                NaN
# 129                                                NaN
# 130                                                NaN
# 131                                          spbre:113
#
#                                       0  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ..                                  ...
# 127                       Oj=function(a
# 128                                 NaN
# 129                                 NaN
# 130                                 NaN
# 131  spbrs:55});</script></body></html>
#
#                                                    0.1  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 127  b){if(Qj){var c=_.kf("SCRIPT");c.async=!0;c.ty...
# 128                                                NaN
# 129                                                NaN
# 130                                                NaN
# 131                                                NaN
#
#     .2);top:32px}x:-o-prefocus  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ..                         ...
# 127                          a
# 128                        NaN
# 129                        NaN
# 130                        NaN
# 131                        NaN
#
#     div.gb_bd{border-bottom-color:#ccc}.gb_ja{background:#fff;border:1px solid #ccc;border-color:rgba(0  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 127                                                  b
# 128                                                NaN
# 129                                                NaN
# 130                                                NaN
# 131                                                NaN
#
#                                          0.2  ... 0.142 1.6 72175901.1 0.143  \
# 0                                        NaN  ...   NaN NaN        NaN   NaN
# 1                                        NaN  ...   NaN NaN        NaN   NaN
# 2                                        NaN  ...   NaN NaN        NaN   NaN
# 3                                        NaN  ...   NaN NaN        NaN   NaN
# 4                                        NaN  ...   NaN NaN        NaN   NaN
# ..                                       ...  ...   ...  ..        ...   ...
# 127  c.src);_.Nj("HEAD")[0].appendChild(c)}}  ...   NaN NaN        NaN   NaN
# 128                                      NaN  ...   NaN NaN        NaN   NaN
# 129                                      NaN  ...   NaN NaN        NaN   NaN
# 130                                      NaN  ...   NaN NaN        NaN   NaN
# 131                                      NaN  ...   NaN NaN        NaN   NaN
#
#     0].5 [[null null.57 null.58  \
# 0    NaN    NaN     NaN     NaN
# 1    NaN    NaN     NaN     NaN
# 2    NaN    NaN     NaN     NaN
# 3    NaN    NaN     NaN     NaN
# 4    NaN    NaN     NaN     NaN
# ..   ...    ...     ...     ...
# 127  NaN    NaN     NaN     NaN
# 128  NaN    NaN     NaN     NaN
# 129  NaN    NaN     NaN     NaN
# 130  NaN    NaN     NaN     NaN
# 131  NaN    NaN     NaN     NaN
#
#     https://www.gstatic.com/og/_/js/k=og.qtm.en_US.hV-PHwAdtNQ.es5.O/rt=j/m=qabr,q_dnp,qapid,qads,q_dg/exm=qaaw,qadd,qaid,qein,qhaw,qhba,qhbr,qhch,qhga,qhid,qhin/d=1/ed=1/rs=AA2YrTt9tkKBZuHInPlQq_B9pPXVq56dJQ]]]]  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 127                                                NaN
# 128                                                NaN
# 129                                                NaN
# 130                                                NaN
# 131                                                NaN
#
#     };this.gbar_=this.gbar_||{};(function(_){var window=this;
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 127                                                NaN
# 128                                                NaN
# 129                                                NaN
# 130                                                NaN
# 131                                                NaN
#
# [132 rows x 672 columns]

# %%
# Display the first few rows of the dataset
df.head()

# Convert the columns to appropriate data types if necessary
df['Year'] = df['Year'].astype(str)
df['Enrolling District Number'] = df['Enrolling District Number'].astype(int)
df['Enrolling District Type'] = df['Enrolling District Type'].astype(int)
df['Count of Open Enrolled'] = df['Count of Open Enrolled'].astype(int)
df['Resident District Number'] = df['Resident District Number'].astype(int)
df['Resident District Type'] = df['Resident District Type'].astype(int)

# Basic data exploration
# Grouping by Enrolling District and summing the counts
grouped_df = df.groupby(['Enrolling District']).agg({'Count of Open Enrolled': 'sum'}).reset_index()

# Plotting the total count of open-enrolled students per enrolling district
fig1 = px.bar(grouped_df, x='Enrolling District', y='Count of Open Enrolled',
              title='Total Count of Open-Enrolled Students per Enrolling District')
fig1.show()

# %%
# Grouping by Resident District and summing the counts
grouped_resident_df = df.groupby(['Resident District']).agg({'Count of Open Enrolled': 'sum'}).reset_index()

# Plotting the total count of open-enrolled students per resident district
fig2 = px.bar(grouped_resident_df, x='Resident District', y='Count of Open Enrolled',
              title='Total Count of Open-Enrolled Students per Resident District')
fig2.show()

# %%
# Distribution of Open-Enrolled Students across Districts
fig3 = px.pie(grouped_df, names='Enrolling District', values='Count of Open Enrolled',
              title='Distribution of Open-Enrolled Students across Enrolling Districts')
fig3.show()

# %%
fig4 = px.line(df, x='Year', y='Count of Open Enrolled', color='Enrolling District',
               title='Trends of Open Enrollment Over the Years by Enrolling District')
fig4.show()

# %%
# Interactive Table with Plotly
fig5 = go.Figure(data=[go.Table(
    header=dict(values=list(df.columns),
                fill_color='paleturquoise',
                align='left'),
    cells=dict(values=[df[col] for col in df.columns],
               fill_color='lavender',
               align='left'))
])

fig5.show()
